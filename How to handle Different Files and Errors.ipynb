# %%
import pandas as pd

# %% [markdown]
# ### Parse Error

# %%
pd.read_csv(r"C:\Users\syam0\Downloads\data111.csv")
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 pd.read_csv(r"C:\Users\syam0\Downloads\data111.csv")
#
# File ~\Downloads\Saniya Mastan\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
# ...

# %% [markdown]
# ## How to handle ParseError

# %%
pd.read_csv(r"C:\Users\syam0\Downloads\data111.csv",on_bad_lines = "warn")
# default = "error"
# "Skip","warn"
# Out:
# C:\Users\syam0\AppData\Local\Temp\ipykernel_4960\2009821299.py:1: ParserWarning: Skipping line 5: expected 2 fields, saw 3
#
#   pd.read_csv(r"C:\Users\syam0\Downloads\data111.csv",on_bad_lines = "warn")
#   Name  Age
# 0   p1   21
# 1   p2   24
# 2   p3   26

# %% [markdown]
# ### Encoding Error

# %%
pd.read_csv(r"C:\Users\syam0\Downloads\Saniya Mastan\spam.csv")
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 pd.read_csv(r"C:\Users\syam0\Downloads\Saniya Mastan\spam.csv")
#
# File ~\Downloads\Saniya Mastan\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
import encodings

# %%
encodings.aliases.aliases   
##encodings.aliases.aliases return #dict
## keys are acting as encoding
# Out:
# {'646': 'ascii',
#  'ansi_x3.4_1968': 'ascii',
#  'ansi_x3_4_1968': 'ascii',
#  'ansi_x3.4_1986': 'ascii',
#  'cp367': 'ascii',
#  'csascii': 'ascii',
#  'ibm367': 'ascii',
#  'iso646_us': 'ascii',
#  'iso_646.irv_1991': 'ascii',
#  'iso_ir_6': 'ascii',
#  'us': 'ascii',
#  'us_ascii': 'ascii',
#  'base64': 'base64_codec',
#  'base_64': 'base64_codec',
#  'big5_tw': 'big5',
#  'csbig5': 'big5',
#  'big5_hkscs': 'big5hkscs',
#  'hkscs': 'big5hkscs',
#  'bz2': 'bz2_codec',
#  '037': 'cp037',
#  'csibm037': 'cp037',
#  'ebcdic_cp_ca': 'cp037',
#  'ebcdic_cp_nl': 'cp037',
#  'ebcdic_cp_us': 'cp037',
#  'ebcdic_cp_wt': 'cp037',
#  'ibm037': 'cp037',
#  'ibm039': 'cp037',
#  '1026': 'cp1026',
#  'csibm1026': 'cp1026',
#  'ibm1026': 'cp1026',
#  '1125': 'cp1125',
#  'ibm1125': 'cp1125',
#  'cp866u': 'cp1125',
#  'ruscii': 'cp1125',
#  '1140': 'cp1140',
#  'ibm1140': 'cp1140',
#  '1250': 'cp1250',
#  'windows_1250': 'cp1250',
#  '1251': 'cp1251',
#  'windows_1251': 'cp1251',
# ...

# %%
l=encodings.aliases.aliases.keys()

# %%
len(l)
# Out:
# 326

# %% [markdown]
# ### How to Handle Encoding Error

# %%
l2 = ["utf-8","latin","utf-16"]

# %%
for i in l2:
    try:
        pd.read_csv(r"C:\Users\syam0\Downloads\Saniya Mastan\spam.csv",encoding=i)
        print("{} is correct encoding".format(i))
    except UnicodeDecodeError:
        print("{} is not correct encoding".format(i))
# Out:
# utf-8 is not correct encoding
# latin is correct encoding
# utf-16 is not correct encoding

# %%
pd.read_csv(r"C:\Users\syam0\Downloads\Saniya Mastan\spam.csv",encoding="latin")
# Out:
#         v1                                                 v2 Unnamed: 2  \
# 0      ham  Go until jurong point, crazy.. Available only ...        NaN
# 1      ham                      Ok lar... Joking wif u oni...        NaN
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3      ham  U dun say so early hor... U c already then say...        NaN
# 4      ham  Nah I don't think he goes to usf, he lives aro...        NaN
# ...    ...                                                ...        ...
# 5567  spam  This is the 2nd time we have tried 2 contact u...        NaN
# 5568   ham              Will Ì_ b going to esplanade fr home?        NaN
# 5569   ham  Pity, * was in mood for that. So...any other s...        NaN
# 5570   ham  The guy did some bitching but I acted like i'd...        NaN
# 5571   ham                         Rofl. Its true to its name        NaN
#
#      Unnamed: 3 Unnamed: 4
# 0           NaN        NaN
# 1           NaN        NaN
# ...

# %%
l1=[]
for i in l:
    try:
        pd.read_csv(r"C:\Users\syam0\Downloads\Saniya Mastan\spam.csv",encoding=i,on_bad_lines="skip")
        print("{} is correct encoding".format(i))
    except UnicodeDecodeError:
        print("{} is not correct encoding".format(i))
    except LookupError:
        print("{} is not supported".format(i))
        l1.append(i)
# Out:
# 646 is not correct encoding
# ansi_x3.4_1968 is not correct encoding
# ansi_x3_4_1968 is not correct encoding
# ansi_x3.4_1986 is not correct encoding
# cp367 is not correct encoding
# csascii is not correct encoding
# ibm367 is not correct encoding
# iso646_us is not correct encoding
# iso_646.irv_1991 is not correct encoding
# iso_ir_6 is not correct encoding
# us is not correct encoding
# us_ascii is not correct encoding
# base64 is not supported
# base_64 is not supported
# big5_tw is not correct encoding
# csbig5 is not correct encoding
# big5_hkscs is not correct encoding
# hkscs is not correct encoding
# bz2 is not supported
# 037 is correct encoding
# csibm037 is correct encoding
# ebcdic_cp_ca is correct encoding
# ebcdic_cp_nl is correct encoding
# ebcdic_cp_us is correct encoding
# ebcdic_cp_wt is correct encoding
# ibm037 is correct encoding
# ibm039 is correct encoding
# 1026 is correct encoding
# csibm1026 is correct encoding
# ibm1026 is correct encoding
# ...

# %%
l1
# Out:
# ['base64',
#  'base_64',
#  'bz2',
#  'hex',
#  'csHPRoman8',
#  'quopri',
#  'quoted_printable',
#  'quotedprintable',
#  'rot13',
#  'uu',
#  'zip',
#  'zlib']

# %%
pd.read_csv(r"C:\Users\syam0\Downloads\Saniya Mastan\spam.csv",encoding="latin")
# Out:
#         v1                                                 v2 Unnamed: 2  \
# 0      ham  Go until jurong point, crazy.. Available only ...        NaN
# 1      ham                      Ok lar... Joking wif u oni...        NaN
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3      ham  U dun say so early hor... U c already then say...        NaN
# 4      ham  Nah I don't think he goes to usf, he lives aro...        NaN
# ...    ...                                                ...        ...
# 5567  spam  This is the 2nd time we have tried 2 contact u...        NaN
# 5568   ham              Will Ì_ b going to esplanade fr home?        NaN
# 5569   ham  Pity, * was in mood for that. So...any other s...        NaN
# 5570   ham  The guy did some bitching but I acted like i'd...        NaN
# 5571   ham                         Rofl. Its true to its name        NaN
#
#      Unnamed: 3 Unnamed: 4
# 0           NaN        NaN
# 1           NaN        NaN
# ...

# %% [markdown]
# ### Issue  Out of Memory

# %%
files = pd.read_csv(r"C:\Users\syam0\Downloads\Saniya Mastan\spam.csv",encoding="latin",chunksize=100)

for chunk in files:
    print(chunk.head(2))
    print("*"*50)
# Out:
#     v1                                                 v2 Unnamed: 2  \
# 0  ham  Go until jurong point, crazy.. Available only ...        NaN
# 1  ham                      Ok lar... Joking wif u oni...        NaN
#
#   Unnamed: 3  Unnamed: 4
# 0        NaN         NaN
# 1        NaN         NaN
# **************************************************
#       v1                                                 v2  Unnamed: 2  \
# 100  ham  Okay name ur price as long as its legal! Wen c...         NaN
# 101  ham  I'm still looking for a car to buy. And have n...         NaN
#
#      Unnamed: 3  Unnamed: 4
# 100         NaN         NaN
# 101         NaN         NaN
# **************************************************
#       v1                                                 v2 Unnamed: 2  \
# 200  ham                       I sent you  &lt;#&gt;  bucks        NaN
# 201  ham  Hello darlin ive finished college now so txt m...        NaN
#
#     Unnamed: 3 Unnamed: 4
# ...

# %%
files = pd.read_csv(r"C:\Users\syam0\Downloads\Saniya Mastan\spam.csv",encoding="latin",chunksize=100)

for chunk in files:
    print(chunk.head(2))
    print("*"*50)
# Out:
#     v1                                                 v2 Unnamed: 2  \
# 0  ham  Go until jurong point, crazy.. Available only ...        NaN
# 1  ham                      Ok lar... Joking wif u oni...        NaN
#
#   Unnamed: 3  Unnamed: 4
# 0        NaN         NaN
# 1        NaN         NaN
# **************************************************
#       v1                                                 v2  Unnamed: 2  \
# 100  ham  Okay name ur price as long as its legal! Wen c...         NaN
# 101  ham  I'm still looking for a car to buy. And have n...         NaN
#
#      Unnamed: 3  Unnamed: 4
# 100         NaN         NaN
# 101         NaN         NaN
# **************************************************
#       v1                                                 v2 Unnamed: 2  \
# 200  ham                       I sent you  &lt;#&gt;  bucks        NaN
# 201  ham  Hello darlin ive finished college now so txt m...        NaN
#
#     Unnamed: 3 Unnamed: 4
# ...

# %%
c
# Out:
# 56

# %% [markdown]
# #### polars

# %%
import time

# %%
x = time.time() # starting time## sec
data1= pd.read_csv(r"C:\Users\syam0\Downloads\Saniya Mastan\spam.csv",encoding ="latin")
y=time.time()  # ending time

# %%
y-x
# Out:
# 0.02635931968688965

# %%
pip install polars
# Out:
# ...
#   Using cached polars-1.14.0-cp39-abi3-win_amd64.whl.metadata (15 kB)
# Using cached polars-1.14.0-cp39-abi3-win_amd64.whl (35.3 MB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import polars

# %%
x = time.time() # starting time## sec
data2= polars.read_csv(r"C:\Users\syam0\Downloads\Saniya Mastan\spam.csv",encoding ="latin")
y=time.time()

# %%
y-x

# %%
data = pd.read_csv(r"C:\Users\syam0\Downloads\Saniya Mastan\spam.csv",encoding ="latin")

# %%
data
# Out:
#         v1                                                 v2 Unnamed: 2  \
# 0      ham  Go until jurong point, crazy.. Available only ...        NaN
# 1      ham                      Ok lar... Joking wif u oni...        NaN
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3      ham  U dun say so early hor... U c already then say...        NaN
# 4      ham  Nah I don't think he goes to usf, he lives aro...        NaN
# ...    ...                                                ...        ...
# 5567  spam  This is the 2nd time we have tried 2 contact u...        NaN
# 5568   ham              Will Ì_ b going to esplanade fr home?        NaN
# 5569   ham  Pity, * was in mood for that. So...any other s...        NaN
# 5570   ham  The guy did some bitching but I acted like i'd...        NaN
# 5571   ham                         Rofl. Its true to its name        NaN
#
#      Unnamed: 3 Unnamed: 4
# 0           NaN        NaN
# 1           NaN        NaN
# ...

# %%
data[["v1","v2"]].to_csv(r"C:\Users\syam0\Downloads\Saniya Mastan\spam1.csv",mode="x") ## always use x mode
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 data[["v1","v2"]].to_csv(r"C:\Users\syam0\Downloads\Saniya Mastan\spam1.csv",mode="x")
#
# File ~\Downloads\Saniya Mastan\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# ...
